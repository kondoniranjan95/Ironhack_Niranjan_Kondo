# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50

# %%
main_data= pd.read_csv('Data_Marketing_Customer_Analysis_Round2.csv')

# %%
main_data.columns= [item.lower() for item in main_data.columns]

# %%
main_data= main_data.rename(columns={'st':'state',"customer lifetime value":"cust_life_val","employmentstatus":"employ_status","monthly premium auto":"month_prem_auto",
                          "number of open complaints":"no_open_compl","number of policies":"no_of_policies","policy type":"policy_type",
                        "vehicle class":"veh_class","total claim amount":"tot_claim_amt","vehicle size":"vehicle_size",
                                     "vehicle type":"vehicle_type","renew offer type":"renew_off_type","sales channel":"sales_channel"
                       })

# %%
main_data
# Out:
#         srno customer       state  cust_life_val response  coverage education  \
# 0          0  DK49336     Arizona    4809.216960       No     Basic   College
# 1          1  KX64629  California    2228.525238       No     Basic   College
# 2          2  LZ68649  Washington   14947.917300       No     Basic  Bachelor
# 3          3  XL78013      Oregon   22332.439460      Yes  Extended   College
# 4          4  QA50777      Oregon    9025.067525       No   Premium  Bachelor
# ...      ...      ...         ...            ...      ...       ...       ...
# 10905  10905  FE99816      Nevada   15563.369440       No   Premium  Bachelor
# 10906  10906  KX53892      Oregon    5259.444853       No     Basic   College
# 10907  10907  TL39050     Arizona   23893.304100       No  Extended  Bachelor
# 10908  10908  WA60547  California   11971.977650       No   Premium   College
# 10909  10909  IV32877         NaN    6857.519928      NaN     Basic  Bachelor
#
#       effective to date  employ_status gender  ...  no_open_compl  \
# 0             2/18/2011       Employed      M  ...            0.0
# 1             1/18/2011     Unemployed      F  ...            0.0
# 2             2/10/2011       Employed      M  ...            0.0
# 3             1/11/2011       Employed      M  ...            0.0
# 4             1/17/2011  Medical Leave      F  ...            NaN
# ...                 ...            ...    ...  ...            ...
# 10905         1/19/2011     Unemployed      F  ...            NaN
# 10906          1/6/2011       Employed      F  ...            0.0
# 10907          2/6/2011       Employed      F  ...            0.0
# 10908         2/13/2011       Employed      F  ...            4.0
# 10909          1/8/2011     Unemployed      M  ...            0.0
#
#       no_of_policies     policy_type        policy  renew_off_type  \
# 0                  9  Corporate Auto  Corporate L3          Offer3
# 1                  1   Personal Auto   Personal L3          Offer4
# 2                  2   Personal Auto   Personal L3          Offer3
# 3                  2  Corporate Auto  Corporate L3          Offer2
# 4                  7   Personal Auto   Personal L2          Offer1
# ...              ...             ...           ...             ...
# 10905              7   Personal Auto   Personal L1          Offer3
# 10906              6   Personal Auto   Personal L3          Offer2
# 10907              2  Corporate Auto  Corporate L3          Offer1
# 10908              6   Personal Auto   Personal L1          Offer1
# 10909              3   Personal Auto   Personal L1          Offer4
#
#        sales_channel  tot_claim_amt      veh_class vehicle_size vehicle_type
# 0              Agent     292.800000  Four-Door Car      Medsize          NaN
# 1        Call Center     744.924331  Four-Door Car      Medsize          NaN
# 2        Call Center     480.000000            SUV      Medsize            A
# 3             Branch     484.013411  Four-Door Car      Medsize            A
# 4             Branch     707.925645  Four-Door Car      Medsize          NaN
# ...              ...            ...            ...          ...          ...
# 10905            Web    1214.400000     Luxury Car      Medsize            A
# 10906         Branch     273.018929  Four-Door Car      Medsize            A
# 10907            Web     381.306996     Luxury SUV      Medsize          NaN
# 10908         Branch     618.288849            SUV      Medsize            A
# 10909            Web    1021.719397            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
main_data= main_data.drop(columns=["customer"])
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   srno                           10910 non-null  int64
#  1   state                          10279 non-null  object
#  2   cust_life_val                  10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective to date              10910 non-null  object
#  7   employ_status                  10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location code                  10910 non-null  object
#  11  marital status                 10910 non-null  object
#  12  month_prem_auto                10910 non-null  int64
#  13  months since last claim        10277 non-null  float64
#  14  months since policy inception  10910 non-null  int64
#  15  no_open_compl                  10277 non-null  float64
#  16  no_of_policies                 10910 non-null  int64
#  17  policy_type                    10910 non-null  object
#  18  policy                         10910 non-null  object
#  19  renew_off_type                 10910 non-null  object
#  20  sales_channel                  10910 non-null  object
#  21  tot_claim_amt                  10910 non-null  float64
#  22  veh_class                      10288 non-null  object
#  23  vehicle_size                   10288 non-null  object
#  24  vehicle_type                   5428 non-null   object
# dtypes: float64(4), int64(5), object(16)
# memory usage: 2.1+ MB

# %%
main_data.state.value_counts()
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: state, dtype: int64

# %%
main_data["state"]= main_data["state"].str.lower()
main_data["education"]= main_data["education"].str.lower()
main_data["policy_type"]= main_data["policy_type"].str.lower()
main_data["policy"]= main_data["policy"].str.lower()
main_data["veh_class"]= main_data["veh_class"].str.lower()
main_data["employ_status"]= main_data["employ_status"].str.lower()
main_data["renew_off_type"]= main_data["renew_off_type"].str.lower()
main_data["sales_channel"]= main_data["sales_channel"].str.lower()
main_data["vehicle_size"]= main_data["vehicle_size"].str.lower()

# %%
main_data
# Out:
#         srno       state  cust_life_val response  coverage education  \
# 0          0     arizona    4809.216960       No     Basic   college
# 1          1  california    2228.525238       No     Basic   college
# 2          2  washington   14947.917300       No     Basic  bachelor
# 3          3      oregon   22332.439460      Yes  Extended   college
# 4          4      oregon    9025.067525       No   Premium  bachelor
# ...      ...         ...            ...      ...       ...       ...
# 10905  10905      nevada   15563.369440       No   Premium  bachelor
# 10906  10906      oregon    5259.444853       No     Basic   college
# 10907  10907     arizona   23893.304100       No  Extended  bachelor
# 10908  10908  california   11971.977650       No   Premium   college
# 10909  10909         NaN    6857.519928      NaN     Basic  bachelor
#
#       effective to date  employ_status gender  income  ... no_open_compl  \
# 0             2/18/2011       employed      M   48029  ...           0.0
# 1             1/18/2011     unemployed      F       0  ...           0.0
# 2             2/10/2011       employed      M   22139  ...           0.0
# 3             1/11/2011       employed      M   49078  ...           0.0
# 4             1/17/2011  medical leave      F   23675  ...           NaN
# ...                 ...            ...    ...     ...  ...           ...
# 10905         1/19/2011     unemployed      F       0  ...           NaN
# 10906          1/6/2011       employed      F   61146  ...           0.0
# 10907          2/6/2011       employed      F   39837  ...           0.0
# 10908         2/13/2011       employed      F   64195  ...           4.0
# 10909          1/8/2011     unemployed      M       0  ...           0.0
#
#       no_of_policies     policy_type        policy  renew_off_type  \
# 0                  9  corporate auto  corporate l3          offer3
# 1                  1   personal auto   personal l3          offer4
# 2                  2   personal auto   personal l3          offer3
# 3                  2  corporate auto  corporate l3          offer2
# 4                  7   personal auto   personal l2          offer1
# ...              ...             ...           ...             ...
# 10905              7   personal auto   personal l1          offer3
# 10906              6   personal auto   personal l3          offer2
# 10907              2  corporate auto  corporate l3          offer1
# 10908              6   personal auto   personal l1          offer1
# 10909              3   personal auto   personal l1          offer4
#
#        sales_channel  tot_claim_amt      veh_class vehicle_size vehicle_type
# 0              agent     292.800000  four-door car      medsize          NaN
# 1        call center     744.924331  four-door car      medsize          NaN
# 2        call center     480.000000            suv      medsize            A
# 3             branch     484.013411  four-door car      medsize            A
# 4             branch     707.925645  four-door car      medsize          NaN
# ...              ...            ...            ...          ...          ...
# 10905            web    1214.400000     luxury car      medsize            A
# 10906         branch     273.018929  four-door car      medsize            A
# 10907            web     381.306996     luxury suv      medsize          NaN
# 10908         branch     618.288849            suv      medsize            A
# 10909            web    1021.719397            suv      medsize          NaN
#
# [10910 rows x 25 columns]

# %% [markdown]
# ### Finding and cleaning nan in the data

# %%
main_data["state"]= main_data.state.fillna("Unknown")
main_data
# Out:
#         srno       state  cust_life_val response  coverage education  \
# 0          0     arizona    4809.216960       No     Basic   college
# 1          1  california    2228.525238       No     Basic   college
# 2          2  washington   14947.917300       No     Basic  bachelor
# 3          3      oregon   22332.439460      Yes  Extended   college
# 4          4      oregon    9025.067525       No   Premium  bachelor
# ...      ...         ...            ...      ...       ...       ...
# 10905  10905      nevada   15563.369440       No   Premium  bachelor
# 10906  10906      oregon    5259.444853       No     Basic   college
# 10907  10907     arizona   23893.304100       No  Extended  bachelor
# 10908  10908  california   11971.977650       No   Premium   college
# 10909  10909     Unknown    6857.519928      NaN     Basic  bachelor
#
#       effective to date  employ_status gender  income  ... no_open_compl  \
# 0             2/18/2011       employed      M   48029  ...           0.0
# 1             1/18/2011     unemployed      F       0  ...           0.0
# 2             2/10/2011       employed      M   22139  ...           0.0
# 3             1/11/2011       employed      M   49078  ...           0.0
# 4             1/17/2011  medical leave      F   23675  ...           NaN
# ...                 ...            ...    ...     ...  ...           ...
# 10905         1/19/2011     unemployed      F       0  ...           NaN
# 10906          1/6/2011       employed      F   61146  ...           0.0
# 10907          2/6/2011       employed      F   39837  ...           0.0
# 10908         2/13/2011       employed      F   64195  ...           4.0
# 10909          1/8/2011     unemployed      M       0  ...           0.0
#
#       no_of_policies     policy_type        policy  renew_off_type  \
# 0                  9  corporate auto  corporate l3          offer3
# 1                  1   personal auto   personal l3          offer4
# 2                  2   personal auto   personal l3          offer3
# 3                  2  corporate auto  corporate l3          offer2
# 4                  7   personal auto   personal l2          offer1
# ...              ...             ...           ...             ...
# 10905              7   personal auto   personal l1          offer3
# 10906              6   personal auto   personal l3          offer2
# 10907              2  corporate auto  corporate l3          offer1
# 10908              6   personal auto   personal l1          offer1
# 10909              3   personal auto   personal l1          offer4
#
#        sales_channel  tot_claim_amt      veh_class vehicle_size vehicle_type
# 0              agent     292.800000  four-door car      medsize          NaN
# 1        call center     744.924331  four-door car      medsize          NaN
# 2        call center     480.000000            suv      medsize            A
# 3             branch     484.013411  four-door car      medsize            A
# 4             branch     707.925645  four-door car      medsize          NaN
# ...              ...            ...            ...          ...          ...
# 10905            web    1214.400000     luxury car      medsize            A
# 10906         branch     273.018929  four-door car      medsize            A
# 10907            web     381.306996     luxury suv      medsize          NaN
# 10908         branch     618.288849            suv      medsize            A
# 10909            web    1021.719397            suv      medsize          NaN
#
# [10910 rows x 25 columns]

# %%
main_data["response"]= main_data.response.fillna("Unknown")
main_data
# Out:
#         srno       state  cust_life_val response  coverage education  \
# 0          0     arizona    4809.216960       No     Basic   college
# 1          1  california    2228.525238       No     Basic   college
# 2          2  washington   14947.917300       No     Basic  bachelor
# 3          3      oregon   22332.439460      Yes  Extended   college
# 4          4      oregon    9025.067525       No   Premium  bachelor
# ...      ...         ...            ...      ...       ...       ...
# 10905  10905      nevada   15563.369440       No   Premium  bachelor
# 10906  10906      oregon    5259.444853       No     Basic   college
# 10907  10907     arizona   23893.304100       No  Extended  bachelor
# 10908  10908  california   11971.977650       No   Premium   college
# 10909  10909     Unknown    6857.519928  Unknown     Basic  bachelor
#
#       effective to date  employ_status gender  income  ... no_open_compl  \
# 0             2/18/2011       employed      M   48029  ...           0.0
# 1             1/18/2011     unemployed      F       0  ...           0.0
# 2             2/10/2011       employed      M   22139  ...           0.0
# 3             1/11/2011       employed      M   49078  ...           0.0
# 4             1/17/2011  medical leave      F   23675  ...           NaN
# ...                 ...            ...    ...     ...  ...           ...
# 10905         1/19/2011     unemployed      F       0  ...           NaN
# 10906          1/6/2011       employed      F   61146  ...           0.0
# 10907          2/6/2011       employed      F   39837  ...           0.0
# 10908         2/13/2011       employed      F   64195  ...           4.0
# 10909          1/8/2011     unemployed      M       0  ...           0.0
#
#       no_of_policies     policy_type        policy  renew_off_type  \
# 0                  9  corporate auto  corporate l3          offer3
# 1                  1   personal auto   personal l3          offer4
# 2                  2   personal auto   personal l3          offer3
# 3                  2  corporate auto  corporate l3          offer2
# 4                  7   personal auto   personal l2          offer1
# ...              ...             ...           ...             ...
# 10905              7   personal auto   personal l1          offer3
# 10906              6   personal auto   personal l3          offer2
# 10907              2  corporate auto  corporate l3          offer1
# 10908              6   personal auto   personal l1          offer1
# 10909              3   personal auto   personal l1          offer4
#
#        sales_channel  tot_claim_amt      veh_class vehicle_size vehicle_type
# 0              agent     292.800000  four-door car      medsize          NaN
# 1        call center     744.924331  four-door car      medsize          NaN
# 2        call center     480.000000            suv      medsize            A
# 3             branch     484.013411  four-door car      medsize            A
# 4             branch     707.925645  four-door car      medsize          NaN
# ...              ...            ...            ...          ...          ...
# 10905            web    1214.400000     luxury car      medsize            A
# 10906         branch     273.018929  four-door car      medsize            A
# 10907            web     381.306996     luxury suv      medsize          NaN
# 10908         branch     618.288849            suv      medsize            A
# 10909            web    1021.719397            suv      medsize          NaN
#
# [10910 rows x 25 columns]

# %%
average_cust_life_val= np.mean(main_data["cust_life_val"])
main_data["cust_life_val"]= main_data.cust_life_val.fillna(average_cust_life_val)
main_data
# Out:
#         srno       state  cust_life_val response  coverage education  \
# 0          0     arizona    4809.216960       No     Basic   college
# 1          1  california    2228.525238       No     Basic   college
# 2          2  washington   14947.917300       No     Basic  bachelor
# 3          3      oregon   22332.439460      Yes  Extended   college
# 4          4      oregon    9025.067525       No   Premium  bachelor
# ...      ...         ...            ...      ...       ...       ...
# 10905  10905      nevada   15563.369440       No   Premium  bachelor
# 10906  10906      oregon    5259.444853       No     Basic   college
# 10907  10907     arizona   23893.304100       No  Extended  bachelor
# 10908  10908  california   11971.977650       No   Premium   college
# 10909  10909     Unknown    6857.519928  Unknown     Basic  bachelor
#
#       effective to date  employ_status gender  income  ... no_open_compl  \
# 0             2/18/2011       employed      M   48029  ...           0.0
# 1             1/18/2011     unemployed      F       0  ...           0.0
# 2             2/10/2011       employed      M   22139  ...           0.0
# 3             1/11/2011       employed      M   49078  ...           0.0
# 4             1/17/2011  medical leave      F   23675  ...           NaN
# ...                 ...            ...    ...     ...  ...           ...
# 10905         1/19/2011     unemployed      F       0  ...           NaN
# 10906          1/6/2011       employed      F   61146  ...           0.0
# 10907          2/6/2011       employed      F   39837  ...           0.0
# 10908         2/13/2011       employed      F   64195  ...           4.0
# 10909          1/8/2011     unemployed      M       0  ...           0.0
#
#       no_of_policies     policy_type        policy  renew_off_type  \
# 0                  9  corporate auto  corporate l3          offer3
# 1                  1   personal auto   personal l3          offer4
# 2                  2   personal auto   personal l3          offer3
# 3                  2  corporate auto  corporate l3          offer2
# 4                  7   personal auto   personal l2          offer1
# ...              ...             ...           ...             ...
# 10905              7   personal auto   personal l1          offer3
# 10906              6   personal auto   personal l3          offer2
# 10907              2  corporate auto  corporate l3          offer1
# 10908              6   personal auto   personal l1          offer1
# 10909              3   personal auto   personal l1          offer4
#
#        sales_channel  tot_claim_amt      veh_class vehicle_size vehicle_type
# 0              agent     292.800000  four-door car      medsize          NaN
# 1        call center     744.924331  four-door car      medsize          NaN
# 2        call center     480.000000            suv      medsize            A
# 3             branch     484.013411  four-door car      medsize            A
# 4             branch     707.925645  four-door car      medsize          NaN
# ...              ...            ...            ...          ...          ...
# 10905            web    1214.400000     luxury car      medsize            A
# 10906         branch     273.018929  four-door car      medsize            A
# 10907            web     381.306996     luxury suv      medsize          NaN
# 10908         branch     618.288849            suv      medsize            A
# 10909            web    1021.719397            suv      medsize          NaN
#
# [10910 rows x 25 columns]

# %%
mode_no_open_compl= 0
main_data["no_open_compl"]= main_data.no_open_compl.fillna(mode_no_open_compl)
main_data
# Out:
#         srno       state  cust_life_val response  coverage education  \
# 0          0     arizona    4809.216960       No     Basic   college
# 1          1  california    2228.525238       No     Basic   college
# 2          2  washington   14947.917300       No     Basic  bachelor
# 3          3      oregon   22332.439460      Yes  Extended   college
# 4          4      oregon    9025.067525       No   Premium  bachelor
# ...      ...         ...            ...      ...       ...       ...
# 10905  10905      nevada   15563.369440       No   Premium  bachelor
# 10906  10906      oregon    5259.444853       No     Basic   college
# 10907  10907     arizona   23893.304100       No  Extended  bachelor
# 10908  10908  california   11971.977650       No   Premium   college
# 10909  10909     Unknown    6857.519928  Unknown     Basic  bachelor
#
#       effective to date  employ_status gender  income  ... no_open_compl  \
# 0             2/18/2011       employed      M   48029  ...           0.0
# 1             1/18/2011     unemployed      F       0  ...           0.0
# 2             2/10/2011       employed      M   22139  ...           0.0
# 3             1/11/2011       employed      M   49078  ...           0.0
# 4             1/17/2011  medical leave      F   23675  ...           0.0
# ...                 ...            ...    ...     ...  ...           ...
# 10905         1/19/2011     unemployed      F       0  ...           0.0
# 10906          1/6/2011       employed      F   61146  ...           0.0
# 10907          2/6/2011       employed      F   39837  ...           0.0
# 10908         2/13/2011       employed      F   64195  ...           4.0
# 10909          1/8/2011     unemployed      M       0  ...           0.0
#
#       no_of_policies     policy_type        policy  renew_off_type  \
# 0                  9  corporate auto  corporate l3          offer3
# 1                  1   personal auto   personal l3          offer4
# 2                  2   personal auto   personal l3          offer3
# 3                  2  corporate auto  corporate l3          offer2
# 4                  7   personal auto   personal l2          offer1
# ...              ...             ...           ...             ...
# 10905              7   personal auto   personal l1          offer3
# 10906              6   personal auto   personal l3          offer2
# 10907              2  corporate auto  corporate l3          offer1
# 10908              6   personal auto   personal l1          offer1
# 10909              3   personal auto   personal l1          offer4
#
#        sales_channel  tot_claim_amt      veh_class vehicle_size vehicle_type
# 0              agent     292.800000  four-door car      medsize          NaN
# 1        call center     744.924331  four-door car      medsize          NaN
# 2        call center     480.000000            suv      medsize            A
# 3             branch     484.013411  four-door car      medsize            A
# 4             branch     707.925645  four-door car      medsize          NaN
# ...              ...            ...            ...          ...          ...
# 10905            web    1214.400000     luxury car      medsize            A
# 10906         branch     273.018929  four-door car      medsize            A
# 10907            web     381.306996     luxury suv      medsize          NaN
# 10908         branch     618.288849            suv      medsize            A
# 10909            web    1021.719397            suv      medsize          NaN
#
# [10910 rows x 25 columns]

# %%
main_data["vehicle_type"]= main_data.vehicle_type.fillna("unknown")
main_data
# Out:
#         srno       state  cust_life_val response  coverage education  \
# 0          0     arizona    4809.216960       No     Basic   college
# 1          1  california    2228.525238       No     Basic   college
# 2          2  washington   14947.917300       No     Basic  bachelor
# 3          3      oregon   22332.439460      Yes  Extended   college
# 4          4      oregon    9025.067525       No   Premium  bachelor
# ...      ...         ...            ...      ...       ...       ...
# 10905  10905      nevada   15563.369440       No   Premium  bachelor
# 10906  10906      oregon    5259.444853       No     Basic   college
# 10907  10907     arizona   23893.304100       No  Extended  bachelor
# 10908  10908  california   11971.977650       No   Premium   college
# 10909  10909     Unknown    6857.519928  Unknown     Basic  bachelor
#
#       effective to date  employ_status gender  income  ... no_open_compl  \
# 0             2/18/2011       employed      M   48029  ...           0.0
# 1             1/18/2011     unemployed      F       0  ...           0.0
# 2             2/10/2011       employed      M   22139  ...           0.0
# 3             1/11/2011       employed      M   49078  ...           0.0
# 4             1/17/2011  medical leave      F   23675  ...           0.0
# ...                 ...            ...    ...     ...  ...           ...
# 10905         1/19/2011     unemployed      F       0  ...           0.0
# 10906          1/6/2011       employed      F   61146  ...           0.0
# 10907          2/6/2011       employed      F   39837  ...           0.0
# 10908         2/13/2011       employed      F   64195  ...           4.0
# 10909          1/8/2011     unemployed      M       0  ...           0.0
#
#       no_of_policies     policy_type        policy  renew_off_type  \
# 0                  9  corporate auto  corporate l3          offer3
# 1                  1   personal auto   personal l3          offer4
# 2                  2   personal auto   personal l3          offer3
# 3                  2  corporate auto  corporate l3          offer2
# 4                  7   personal auto   personal l2          offer1
# ...              ...             ...           ...             ...
# 10905              7   personal auto   personal l1          offer3
# 10906              6   personal auto   personal l3          offer2
# 10907              2  corporate auto  corporate l3          offer1
# 10908              6   personal auto   personal l1          offer1
# 10909              3   personal auto   personal l1          offer4
#
#        sales_channel  tot_claim_amt      veh_class vehicle_size vehicle_type
# 0              agent     292.800000  four-door car      medsize      unknown
# 1        call center     744.924331  four-door car      medsize      unknown
# 2        call center     480.000000            suv      medsize            A
# 3             branch     484.013411  four-door car      medsize            A
# 4             branch     707.925645  four-door car      medsize      unknown
# ...              ...            ...            ...          ...          ...
# 10905            web    1214.400000     luxury car      medsize            A
# 10906         branch     273.018929  four-door car      medsize            A
# 10907            web     381.306996     luxury suv      medsize      unknown
# 10908         branch     618.288849            suv      medsize            A
# 10909            web    1021.719397            suv      medsize      unknown
#
# [10910 rows x 25 columns]

# %%
main_data['months since last claim'].isnull().sum()
# Out:
# 633

# %%
main_data= main_data.drop(columns=['months since last claim'])
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   srno                           10910 non-null  int64
#  1   state                          10910 non-null  object
#  2   cust_life_val                  10910 non-null  float64
#  3   response                       10910 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective to date              10910 non-null  object
#  7   employ_status                  10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location code                  10910 non-null  object
#  11  marital status                 10910 non-null  object
#  12  month_prem_auto                10910 non-null  int64
#  13  months since policy inception  10910 non-null  int64
#  14  no_open_compl                  10910 non-null  float64
#  15  no_of_policies                 10910 non-null  int64
#  16  policy_type                    10910 non-null  object
#  17  policy                         10910 non-null  object
#  18  renew_off_type                 10910 non-null  object
#  19  sales_channel                  10910 non-null  object
#  20  tot_claim_amt                  10910 non-null  float64
#  21  veh_class                      10288 non-null  object
#  22  vehicle_size                   10288 non-null  object
#  23  vehicle_type                   10910 non-null  object
# dtypes: float64(3), int64(5), object(16)
# memory usage: 2.0+ MB

# %%
main_data= main_data.drop(columns=['srno'])
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          10910 non-null  object
#  1   cust_life_val                  10910 non-null  float64
#  2   response                       10910 non-null  object
#  3   coverage                       10910 non-null  object
#  4   education                      10910 non-null  object
#  5   effective to date              10910 non-null  object
#  6   employ_status                  10910 non-null  object
#  7   gender                         10910 non-null  object
#  8   income                         10910 non-null  int64
#  9   location code                  10910 non-null  object
#  10  marital status                 10910 non-null  object
#  11  month_prem_auto                10910 non-null  int64
#  12  months since policy inception  10910 non-null  int64
#  13  no_open_compl                  10910 non-null  float64
#  14  no_of_policies                 10910 non-null  int64
#  15  policy_type                    10910 non-null  object
#  16  policy                         10910 non-null  object
#  17  renew_off_type                 10910 non-null  object
#  18  sales_channel                  10910 non-null  object
#  19  tot_claim_amt                  10910 non-null  float64
#  20  veh_class                      10288 non-null  object
#  21  vehicle_size                   10288 non-null  object
#  22  vehicle_type                   10910 non-null  object
# dtypes: float64(3), int64(4), object(16)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Splitting X and y

# %%
train=main_data.sample(frac=0.25,random_state=200)
main_data.reset_index()
train.reset_index()
# Out:
#       index       state  cust_life_val response  coverage  \
# 0      5802     arizona    3920.511337       No   Premium
# 1      3381     arizona    9983.128441       No  Extended
# 2     10376  california    7901.744238       No     Basic
# 3      8059  california    4872.016380       No     Basic
# 4      4130      oregon    8231.223361       No     Basic
# ...     ...         ...            ...      ...       ...
# 2723   1233  california    8996.774075       No     Basic
# 2724   2789  california    7295.332712       No  Extended
# 2725   9608     arizona    2345.262087       No     Basic
# 2726  10567      oregon    2854.266940       No     Basic
# 2727   4661  washington    2513.117202       No     Basic
#
#                  education effective to date employ_status gender  income  \
# 0     high school or below          2/4/2011    unemployed      F       0
# 1                  college          1/6/2011    unemployed      F       0
# 2     high school or below          2/2/2011    unemployed      M       0
# 3                   master         1/11/2011    unemployed      M       0
# 4                  college         1/11/2011    unemployed      F       0
# ...                    ...               ...           ...    ...     ...
# 2723  high school or below         2/13/2011      employed      M   49706
# 2724  high school or below         2/15/2011      employed      F   34062
# 2725               college          2/3/2011      employed      M   51397
# 2726  high school or below         2/10/2011      employed      F   34807
# 2727              bachelor         2/14/2011      employed      M   22475
#
#       ... no_open_compl no_of_policies     policy_type        policy  \
# 0     ...           1.0              1   personal auto   personal l3
# 1     ...           0.0              2   personal auto   personal l1
# 2     ...           0.0              5   personal auto   personal l3
# 3     ...           0.0              7   personal auto   personal l2
# 4     ...           0.0              4   personal auto   personal l3
# ...   ...           ...            ...             ...           ...
# 2723  ...           0.0              3   personal auto   personal l3
# 2724  ...           0.0              3  corporate auto  corporate l3
# 2725  ...           0.0              1   personal auto   personal l3
# 2726  ...           0.0              1   personal auto   personal l3
# 2727  ...           1.0              1   personal auto   personal l3
#
#       renew_off_type  sales_channel tot_claim_amt      veh_class vehicle_size  \
# 0             offer3         branch    525.392239   two-door car        large
# 1             offer3    call center    669.600000  four-door car      medsize
# 2             offer1    call center   1258.327804            NaN          NaN
# 3             offer1          agent    307.200000            NaN          NaN
# 4             offer1            web    373.073162            suv      medsize
# ...              ...            ...           ...            ...          ...
# 2723          offer2    call center    617.515196            suv      medsize
# 2724          offer3          agent    603.350571  four-door car      medsize
# 2725          offer1         branch    292.800000  four-door car      medsize
# 2726          offer1          agent    472.043042   two-door car        small
# 2727          offer2          agent    307.200000  four-door car        large
#
#      vehicle_type
# 0         unknown
# 1               A
# 2               A
# 3               A
# 4         unknown
# ...           ...
# 2723      unknown
# 2724      unknown
# 2725      unknown
# 2726            A
# 2727      unknown
#
# [2728 rows x 24 columns]

# %% [markdown]
# ### Correlation matrix

# %%
corr = main_data.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %% [markdown]
# ### Predictive modeling

# %% [markdown]
# ### X Y split

# %%
X=main_data.drop('tot_claim_amt', axis=1)
y= main_data.tot_claim_amt

# %%
X=X._get_numeric_data()
X
# Out:
#        cust_life_val  income  month_prem_auto  months since policy inception  \
# 0        4809.216960   48029               61                             52
# 1        2228.525238       0               64                             26
# 2       14947.917300   22139              100                             31
# 3       22332.439460   49078               97                              3
# 4        9025.067525   23675              117                             31
# ...              ...     ...              ...                            ...
# 10905   15563.369440       0              253                             40
# 10906    5259.444853   61146               65                             68
# 10907   23893.304100   39837              201                             63
# 10908   11971.977650   64195              158                             27
# 10909    6857.519928       0              101                              1
#
#        no_open_compl  no_of_policies
# 0                0.0               9
# 1                0.0               1
# 2                0.0               2
# 3                0.0               2
# 4                0.0               7
# ...              ...             ...
# 10905            0.0               7
# 10906            0.0               6
# 10907            0.0               2
# 10908            4.0               6
# 10909            0.0               3
#
# [10910 rows x 6 columns]

# %% [markdown]
# ### Standardize

# %%
X_scaled=StandardScaler().fit_transform(X)
X_scaled.shape
# Out:
# (10910, 6)

# %%
X_scaled
# Out:
# array([[-0.46610505,  0.34563485, -0.93481904,  0.13987654, -0.4066559 ,
#          2.50945468],
#        [-0.84094593, -1.23646244, -0.84771343, -0.79070911, -0.4066559 ,
#         -0.82492205],
#        [ 1.00652314, -0.50719362,  0.19755381, -0.61175033, -0.4066559 ,
#         -0.40812496],
#        ...,
#        [ 2.30582467,  0.07578661,  3.13010912,  0.53358586, -0.4066559 ,
#         -0.40812496],
#        [ 0.5742732 ,  0.87815031,  1.88159547, -0.75491735,  4.08725734,
#          1.25906341],
#        [-0.16859268, -1.23646244,  0.22658901, -1.685503  , -0.4066559 ,
#          0.00867213]])

# %%
X_train, X_test, y_train, y_test=train_test_split(X_scaled, y, test_size=.20)

# %%
X_train
# Out:
# array([[ 0.97761968, -0.20786368, -0.0056926 ,  0.71254464, -0.4066559 ,
#         -0.40812496],
#        [ 0.87357403, -1.23646244,  2.83975711,  1.64313029,  0.71682241,
#          2.09265759],
#        [-0.33368501, -0.1749891 , -0.61543183, -0.96966789, -0.4066559 ,
#          0.00867213],
#        ...,
#        [-0.80390478,  1.64556418, -0.90578384,  0.74833639, -0.4066559 ,
#         -0.82492205],
#        [-0.75303114,  0.25771677, -0.58639662,  0.8199199 , -0.4066559 ,
#         -0.82492205],
#        [-0.46934809,  0.26282254, -0.93481904, -0.54016682, -0.4066559 ,
#          2.50945468]])

# %% [markdown]
# ### Apply regression

# %%
model=LinearRegression()    # model
model.fit(X_train, y_train)   # model train
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)   # model prediction

# %%
y_pred
# Out:
# array([332.20210708, 371.08559917, 414.04481739, ..., 259.09337265,
#        424.69425391, 533.13317551])

# %%
result=pd.DataFrame({"y_test":y_test,"y_pred":y_pred})

# %%
fig, ax = plt.subplots(1,2,figsize=(9,4))
ax[0].plot(y_pred, y_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y_test - y_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")
# Out:
# Text(0.5, 1.0, 'Test Set Residual histogram')

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %% [markdown]
# ### Error calculations

# %%
mse(y_test,y_pred)
# Out:
# 37724.70599621414

# %%
mae(y_test,y_pred)
# Out:
# 139.92297244826125

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5276293526727769
