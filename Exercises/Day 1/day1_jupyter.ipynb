# %% [markdown]
# # Vacation

# %% [markdown]
# * [Purpose](#purpose)
# * [Vacation function](#vacationfunction)
# * [Photo of the person](#photooftheperson)
# * [holiday_preferences function](#holiday_preferencesfunction)
# * [Photo of holiday destination](#photoofholidaydestination)
# * [Things Emily likes to do in Paris](#ThingsemilylikestodoinParis)
# * [Youtube link for PARIS](#YoutubelinkforPARIS)

# %% [markdown]
# ### Purpose <a class="anchor" id="purpose"></a>
# ## This notebook describes the vacation of Emily in Paris

# %%
### Vacation function <a class="anchor" id="vacationfunction"></a>
def vacation(emily):
    return emily

# %% [markdown]
# ### Photo of the person <a class="anchor" id="photooftheperson"></a>
# ![3-Emily-In-Paris-vogue-061020-credit-Netflix.jpg](attachment:3-Emily-In-Paris-vogue-061020-credit-Netflix.jpg)

# %%
### holiday_preferences function <a class="anchor" id="holiday_preferencesfunction"></a>
def holiday_preferences(emily):
    pref1= input(location1)
    pref2= input(location2)
    x= print("Preferred travel location of Emily are",pref1,pref2)
    return x

# %% [markdown]
# ### Photo of holiday destination <a class="anchor" id="photoofholidaydestination"></a>
# ![9c.jpg](attachment:9c.jpg)

# %% [markdown]
# ### Things Emily likes to do in Paris <a class="anchor" id="ThingsemilylikestodoinParis"></a>
# <ul>
# <li><i>Watching Eifel tower</i></li>
# <li><i>Dining</i></li>
# <li><i>Shopping</i></li>
# </ul>

# %% [markdown]
# ### Youtube link for PARIS <a class="anchor" id="YoutubelinkforPARIS"></a>
# <a> href="https://www.youtube.com/watch?v=72kRM86V-dw" >    LINK TO PARIS</a>
